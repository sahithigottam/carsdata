# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename = "/Users/sahithi/Desktop/week4/cars_data.csv"
df= pd.read_csv(filename)

# %%
df
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %%
df.head()
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  \
# 0  User-friendly   Belgium        Antwerpen        51.247239
# 1      analyzing     China            Jinhu        33.025433
# 2       software     China             Gemo        30.916207
# 3     monitoring  Portugal  Queluz de Baixo        38.745168
# 4       Sharable    Latvia         Jaunpils        56.729980
#
#    Dealer Longitude    Color  New Car Purchase Date  Sale Price  Discount  \
# 0          4.440346   Yellow    False    19/07/2009    54806.14    0.2467
# ...

# %%
df.tail()
# Out:
#          Make        Model  Nickname Car Gender Buyer Gender  Buyer Age  \
# 9995    Mazda      Tribute    Cooper       Male         Male         44
# 9996      GMC  Sierra 2500       Dud       Male         Male         40
# 9997  Mercury      Mariner   Chariot       Male         Male         37
# 9998   Daewoo      Leganza     Dynah     Female       Female         21
# 9999   Toyota      Sequoia  Zedekiah     Female         Male         21
#
#         Buzzword      Country             City  Dealer Latitude  \
# 9995    hardware     Pakistan  Chishtiān Mandi        29.919386
# 9996    Enhanced   Costa Rica          Ángeles        10.075000
# 9997  monitoring       Poland        Dąbrowice        52.311923
# 9998    cohesive  Philippines         Villasis        15.901640
# 9999   analyzing  Philippines            Basud        14.048167
#
#       Dealer Longitude Color  New Car Purchase Date  Sale Price  Discount  \
# ...

# %% [markdown]
# # Check for the null values present in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               10000 non-null  object
#  1   Model              10000 non-null  object
#  2   Nickname           10000 non-null  object
#  3   Car Gender         10000 non-null  object
#  4   Buyer Gender       10000 non-null  object
#  5   Buyer Age          10000 non-null  int64
#  6   Buzzword           10000 non-null  object
#  7   Country            10000 non-null  object
#  8   City               10000 non-null  object
#  9   Dealer Latitude    10000 non-null  float64
#  10  Dealer Longitude   10000 non-null  float64
#  11  Color              10000 non-null  object
#  12  New Car            10000 non-null  bool
#  13  Purchase Date      10000 non-null  object
#  14  Sale Price         10000 non-null  float64
#  15  Discount           10000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# car_gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# sale_price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # Plot a bar graph of male vs female buyers participated in the sales.

# %%
plt.figure()
plt.hist((df1[""],df2["Churn"]),label =["male","female",],alpha=0.5)
plt.legend(borderpad= 0.5,fontsize=10)
plt.title("comparison of male and female churns")
plt.show()

# %%
list(df.columns)
# Out:
# ['Make',
#  'Model',
#  'Nickname',
#  'Car Gender',
#  'Buyer Gender',
#  'Buyer Age',
#  'Buzzword',
#  'Country',
#  'City',
#  'Dealer Latitude',
#  'Dealer Longitude',
#  'Color',
#  'New Car',
#  'Purchase Date',
#  'Sale Price',
#  'Discount',
#  'Resell Price',
#  '5-yr Depreciation',
#  'Top Speed',
#  '0-60 Time']

# %%
df.rename(columns={"Car Gender":"car_gender"},inplace=True)

# %%
df.rename(columns={"Sale Price":"sale_price"},inplace=True)

# %%
df.rename(columns={"Resell Price":"Resell_Price"},inplace=True)

# %%
list(df.columns)
# Out:
# ['Make',
#  'Model',
#  'Nickname',
#  'car_gender',
#  'Buyer Gender',
#  'Buyer Age',
#  'Buzzword',
#  'Country',
#  'City',
#  'Dealer Latitude',
#  'Dealer Longitude',
#  'Color',
#  'New Car',
#  'Purchase Date',
#  'sale_price',
#  'Discount',
#  'Resell_Price',
#  '5-yr Depreciation',
#  'Top Speed',
#  '0-60 Time']

# %%
sns.countplot(x='car_gender', data=df)
plt.title('Male vs female buyers')
# Out:
# Text(0.5, 1.0, 'Male vs female buyers')

# %% [markdown]
# # Find the top 5 cars based on their sales price.

# %%
df.sort_values("sale_price",ascending = False)
# Out:
#             Make                 Model   Nickname car_gender Buyer Gender  \
# 5984  Volkswagen             Jetta III    Rachael     Female       Female
# 1270        Audi                    A6      Thorn       Male         Male
# 3460       Lexus                    LX      Aldin     Female         Male
# 9032       Mazda                  MX-6  Sylvester     Female         Male
# 302        Lexus                    ES       Brig     Female         Male
# ...          ...                   ...        ...        ...          ...
# 6241     Lincoln  Continental Mark VII    Malissa     Female       Female
# 6270      Nissan                 240SX     Paloma       Male       Female
# 5956       Mazda                Mazda6     Milzie       Male       Female
# 7234        Ford             Excursion     Patric       Male         Male
# 3513         Geo               Tracker     Nowell       Male         Male
#
#       Buyer Age              Buzzword      Country           City  \
# ...

# %% [markdown]
# df1

# %%
df.describe()
# Out:
#           Buyer Age  Dealer Latitude  Dealer Longitude    sale_price  \
# count  10000.000000     10000.000000      10000.000000  10000.000000
# mean      47.762100        24.820088         43.878248  55350.799983
# std       16.139862        24.585875         70.985736  25888.683650
# min       20.000000       -53.163833       -178.165510  10003.760000
# 25%       34.000000         7.442378          4.400811  33254.517500
# 50%       48.000000        31.049994         38.156212  55629.770000
# 75%       62.000000        44.351935        112.252192  77770.950000
# max       75.000000        71.963470        179.350460  99997.650000
#
#            Discount  Resell Price  5-yr Depreciation     Top Speed  \
# count  10000.000000  10000.000000       10000.000000  10000.000000
# mean       0.350310  25873.349305           0.130596    184.903480
# std        0.201970  13844.768112           0.069593     37.528707
# min        0.000100   2000.840000           0.010000    120.000000
# ...

# %%
pro_sales = pd.DataFrame(df.groupby('Model').sum()["sale_price"])

# %%
pro_sales
# Out:
#           sale_price
# Model
# 09-Mar    1248293.85
# 09-May     422468.32
# 1 Series   393198.63
# 100        313980.50
# 1000       415551.58
# ...              ...
# riolet     331973.17
# tC         828690.85
# xA         140643.16
# xB         766670.73
# xD         570673.36
#
# [957 rows x 1 columns]

# %%
pro_sales = pro_sales.sort_values("sale_price",ascending = False)

# %%
pro_sales[:5]
# Out:
#           sale_price
# Model
# Corvette  3818677.78
# Mustang   3653689.56
# Camaro    2879639.79
# Taurus    2705336.84
# S-Class   2683098.99

# %% [markdown]
# # Find the least 5 cars based on their Resell price.

# %%
retail_sales = pd.DataFrame(df.groupby('Model').sum()["Resell_Price"])

# %%
retail_sales
# Out:
#           Resell_Price
# Model
# 09-Mar       548016.86
# 09-May       224886.81
# 1 Series      77263.16
# 100          166586.48
# 1000         174596.70
# ...                ...
# riolet       174956.57
# tC           251643.49
# xA           105036.29
# xB           352240.58
# xD           311017.72
#
# [957 rows x 1 columns]

# %%
retail_sales = retail_sales.sort_values("Resell_Price",ascending = True)

# %%
retail_sales[:5]
# Out:
#                     Resell_Price
# Model
# Navajo                   2137.61
# 458 Italia               2160.65
# RS 6                     2823.28
# Range Rover Evoque       3134.05
# Outlander Sport          3488.70
